# %%
from azureml.core import Workspace,Dataset,Datastore

# %%
ws=Workspace.from_config()

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data/loan_data.csv")

# %%
dstore=ws.get_default_datastore()

# %%
Dataset.Tabular.register_pandas_dataframe(dataframe=df,target=(dstore,"/loandata"),name="loans",description="loan dataset")
# Out:
# Validating arguments.
# Arguments validated.
# Successfully obtained datastore reference and path.
# Uploading file to /loandata/cbd512e6-0730-47fe-bf88-46ff95382a81/
# Successfully uploaded file to datastore.
# Creating and registering a new dataset.
# Successfully created and registered a new dataset.
# {
#   "source": [
#     "('workspaceblobstore', '/loandata/cbd512e6-0730-47fe-bf88-46ff95382a81/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ReadParquetFile",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "9174958c-e81a-483b-9043-2e28ba018501",
#     "name": "loans",
#     "version": 1,
#     "description": "loan dataset",
#     "workspace": "Workspace.create(name='eymlws', subscription_id='afe91b36-9760-4bb8-9dd6-72761af8d4ef', resource_group='eymlops')"
#   }
# }

# %%
loans_ds=ws.datasets['loans']

# %%
loans_ds
# Out:
# {
#   "source": [
#     "('workspaceblobstore', '/loandata/cbd512e6-0730-47fe-bf88-46ff95382a81/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ReadParquetFile",
#     "DropColumns"
#   ],
#   "registration": {
#     "id": "9174958c-e81a-483b-9043-2e28ba018501",
#     "name": "loans",
#     "version": 1,
#     "description": "loan dataset",
#     "workspace": "Workspace.create(name='eymlws', subscription_id='afe91b36-9760-4bb8-9dd6-72761af8d4ef', resource_group='eymlops')"
#   }
# }

# %%
compute_target=ws.compute_targets["akt-cluster"]

# %% [markdown]
# You will need to create a configuration object that will dictate the use of the
# AzureML-Tutorial Environment when each step gets executed. To do that,
# you will need to create a RunConfiguration using the following code:

# %%
from azureml.core import RunConfiguration

# %%
runconfig=RunConfiguration()
runconfig.environment=ws.environments["AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu"]

# %% [markdown]
# You will then need to define a temporary storage folder where the first step will drop
# the output files. You will use the PipelineData class using the following code:

# %%
from azureml.pipeline.core import PipelineData

# %%
step01_output=PipelineData(
    "training_data",
    datastore=ws.get_default_datastore(),
    is_directory=True)

# %% [markdown]
# In this code, you are creating an intermediate data location named training_
# data, which is stored as a folder in the default datastore that is registered in your
# AzureML workspace. You should not care about the actual path of this temporary
# data, but if you are curious, the actual path of that folder in the default storage
# container is something like azureml/{step01_run_id}/training_data.

# %% [markdown]
# ## Now that you have all the prerequisites for your pipeline's first step, it is time to define it.

# %%
from azureml.pipeline.steps import PythonScriptStep

# %%
step01=PythonScriptStep(script_name="prepare_data.py",
                        source_directory="step01",
                        arguments = [
                             "--dataset", loans_ds.as_named_input('loans'), 
                             "--output-path", step01_output],
                        name="Prepare data",
                        runconfig=runconfig,
                        compute_target=compute_target,
                        outputs=[step01_output],
                        allow_reuse=True)

# %% [markdown]
# This code defines a PythonScriptStep that will be using the source code in the
# step01 folder. It will execute the script named prepare_data.py, passing the
# following arguments:

# %% [markdown]
# • --dataset: This passes the loans_ds dataset ID to that variable. This dataset
# ID is a unique GUID representing the specific version of the dataset as it is
# registered within your AzureML workspace. The code goes one step further and
# makes a call to the as_named_input method. This method is available in both
# FileDataset and TabularDataset and is only applicable when a Run
# executes within the AzureML workspace. To invoke the method, you must provide
# a name, in this case, loans, that can be used within the script to retrieve the
# dataset. The AzureML SDK will make the TabularDataset object available
# within the prepare_data.py script in the input_datasets dictionary of the
# run object. Within the prepare_data.py script, you can get a reference to that
# dataset using the following code:
#
#
# run = Run.get_context()
#
# loans_dataset = run.input_datasets["loans"]

# %% [markdown]
# • --output-path: This passes the PipelineData object you created in previous steps.
# This parameter will be a string representing a path where the script can store its
# output files. The datastore location is mounted to the local storage of the compute
# node that is about to execute the specific step. This mounting path is passed to
# the script, allowing your script to transparently write the outputs directly to
# the datastore.

# %% [markdown]
# The allow_reuse Boolean parameter allows you to reuse the outputs of this
# PythonScriptStep if the inputs of the script and the source code within the
# step01 folder haven't changed since the last execution of the pipeline.

# %% [markdown]
# ## Defining the prerequisites for the second step

# %% [markdown]
# step02 requires a parameter named learning_rate. Instead of hardcoding the learning
# rate hyperparameter of the LightGBM model within your training script, you will
# use a PipelineParameter to pass in this value. This parameter will be defined at
# Pipeline level, and it will be passed to the training script as an argument

# %%
from azureml.pipeline.core import PipelineParameter

# %%
learning_rate_param = PipelineParameter( name="learning_rate", default_value=0.05)

# %% [markdown]
# You will store the trained model in the /models/loans/ folder of the default
# datastore attached to the AzureML workspace. To specify the exact location where
# you want to store the files, you will use the OutputFileDatasetConfig class.

# %%
from azureml.data import OutputFileDatasetConfig

datastore = ws.get_default_datastore()

step02_output = OutputFileDatasetConfig(
 name = "model_store",
 destination = (datastore, '/models/loans/'))

# %% [markdown]
# Now that you have all the prerequisites defined, you can define the second step of
# your Pipeline.

# %%
step02 = PythonScriptStep(
 'train_model.py', 
 source_directory='step02',
 arguments = [
 "--learning-rate", learning_rate_param,
 "--input-path", step01_output,
 "--output-path", step02_output],
 name='Train model',
 runconfig=runconfig,
 compute_target=compute_target,
 inputs=[step01_output],
 outputs=[step02_output]
)

# %% [markdown]
# Similar to the step_01 folder you created in previous steps; this code defines
# a PythonScriptStep that will invoke the train_model.py script located in
# the step02 folder. It will populate the --learning-rate argument using the
# value passed to the PipelineParameter you defined in previous steps. It will also pass
# the output of step_01 to the --input-path argument.
#
# Note that step01_output is also added to the list of inputs of this PythonScriptStep. This forces
# step_02 to wait for step_01 to complete in order to consume the data stored in
# step01_output.
#
# The last script argument is --output-path, where you pass
# the OutputFileDatasetConfig object you created in the previous step. This
# object is also added to the list of outputs of this PythonScriptStep

# %% [markdown]
# ## It's time to define the actual Pipeline you have been building so far

# %%
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[step01, 
step02])

# %% [markdown]
# ## To execute the pipeline, you will need to submit it in an Experiment.

# %%
from azureml.core import Experiment

experiment = Experiment(ws, "pipeline_exp")
pipeline_run = experiment.submit(
 pipeline,
 pipeline_parameters= {
 "learning_rate" : 0.5
 }
)
pipeline_run.wait_for_completion()
# Out:
# Created step Prepare data [88b2da09][3690b903-651a-4e18-9819-48bc1e7812df], (This step will run and generate new outputs)
# Created step Train model [d6fb068c][5d3ab1b2-c8c8-46ba-8e44-7dba9768b2f2], (This step will run and generate new outputs)
# Submitted PipelineRun 5f85466f-1b84-40ae-ad01-2cf7a9d9cc04
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5f85466f-1b84-40ae-ad01-2cf7a9d9cc04?wsid=/subscriptions/afe91b36-9760-4bb8-9dd6-72761af8d4ef/resourcegroups/eymlops/workspaces/eymlws&tid=bdf67597-3a9e-4e19-958e-1d8222afa3de
# PipelineRunId: 5f85466f-1b84-40ae-ad01-2cf7a9d9cc04
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5f85466f-1b84-40ae-ad01-2cf7a9d9cc04?wsid=/subscriptions/afe91b36-9760-4bb8-9dd6-72761af8d4ef/resourcegroups/eymlops/workspaces/eymlws&tid=bdf67597-3a9e-4e19-958e-1d8222afa3de
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: f4aea2da-ed30-4905-b0de-f3093539eb67
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f4aea2da-ed30-4905-b0de-f3093539eb67?wsid=/subscriptions/afe91b36-9760-4bb8-9dd6-72761af8d4ef/resourcegroups/eymlops/workspaces/eymlws&tid=bdf67597-3a9e-4e19-958e-1d8222afa3de
# StepRun( Prepare data ) Status: NotStarted
# StepRun( Prepare data ) Status: Running
#
# StepRun(Prepare data) Execution Summary
# ========================================
# StepRun( Prepare data ) Status: Finished
# {'runId': 'f4aea2da-ed30-4905-b0de-f3093539eb67', 'target': 'akt-cluster', 'status': 'Completed', 'startTimeUtc': '2022-10-27T13:44:02.919156Z', 'endTimeUtc': '2022-10-27T13:45:52.238039Z', 'services': {}, 'properties': {'ContentSnapshotId': 'a6f7357c-342d-4ec8-9861-6e2cf5772b89', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '3690b903-651a-4e18-9819-48bc1e7812df', 'azureml.moduleName': 'Prepare data', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '88b2da09', 'azureml.pipelinerunid': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04', 'azureml.pipeline': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '9174958c-e81a-483b-9043-2e28ba018501'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'loans', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'prepare_data.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--dataset', 'DatasetConsumptionConfig:loans', '--output-path', '$AZUREML_DATAREFERENCE_training_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'akt-cluster', 'dataReferences': {'training_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'loans': {'dataLocation': {'dataset': {'id': '9174958c-e81a-483b-9043-2e28ba018501', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Direct', 'environmentVariableName': 'loans', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu', 'version': '46', 'assetId': 'azureml://registries/azureml/environments/AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu/versions/46', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': True, 'condaDependencies': None, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': None, 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': "FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220902.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/lightgbm\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 pip=20.2.4\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\n    pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'numpy>=1.10,<1.20' \\\n                'scipy~=1.5.0' \\\n                'scikit-learn~=0.24.1' \\\n                'xgboost~=1.4.0' \\\n                'lightgbm~=3.2.0' \\\n                'dask~=2021.10.0' \\\n                'distributed~=2021.10.0' \\\n                'dask-ml~=2021.10.17' \\\n                'adlfs~=0.7.0' \\\n                'ipykernel~=6.0' \\\n                'azureml-core==1.45.0' \\\n                'azureml-defaults==1.45.0' \\\n                'azureml-mlflow==1.45.0' \\\n                'azureml-telemetry==1.45.0'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH", 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, ...
#
#
#
#
# StepRunId: 550eedd7-8aab-43c5-8a9c-4c0e3092088a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/550eedd7-8aab-43c5-8a9c-4c0e3092088a?wsid=/subscriptions/afe91b36-9760-4bb8-9dd6-72761af8d4ef/resourcegroups/eymlops/workspaces/eymlws&tid=bdf67597-3a9e-4e19-958e-1d8222afa3de
# StepRun( Train model ) Status: NotStarted
# StepRun( Train model ) Status: Running
#
# StepRun(Train model) Execution Summary
# =======================================
# StepRun( Train model ) Status: Finished
# {'runId': '550eedd7-8aab-43c5-8a9c-4c0e3092088a', 'target': 'akt-cluster', 'status': 'Completed', 'startTimeUtc': '2022-10-27T13:46:12.137293Z', 'endTimeUtc': '2022-10-27T13:46:29.833216Z', 'services': {}, 'properties': {'ContentSnapshotId': '94d70895-9222-4018-bdbc-2cb13af3f02d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '5d3ab1b2-c8c8-46ba-8e44-7dba9768b2f2', 'azureml.moduleName': 'Train model', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'd6fb068c', 'azureml.pipelinerunid': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04', 'azureml.pipeline': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [{'identifier': {'savedId': '7d23aeb9-c3ea-4983-b7cb-1135cd7a896e'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'model_store'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'models/loans/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "7d23aeb9-c3ea-4983-b7cb-1135cd7a896e",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='eymlws', subscription_id='afe91b36-9760-4bb8-9dd6-72761af8d4ef', resource_group='eymlops')"
#   }
# }}], 'runDefinition': {'script': 'train_model.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--learning-rate', '$AML_PARAMETER_learning_rate', '--input-path', '$AZUREML_DATAREFERENCE_training_data', '--output-path', 'DatasetOutputConfig:model_store'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'akt-cluster', 'dataReferences': {'training_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {'model_store': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': '/models/loans/'}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04', 'azureml.pipelineRun.moduleNodeId': 'd6fb068c', 'azureml.pipelineRun.outputPortName': 'model_store'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu', 'version': '46', 'assetId': 'azureml://registries/azureml/environments/AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu/versions/46', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': True, 'condaDependencies': None, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': None, 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': "FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220902.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/lightgbm\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 pip=20.2.4\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\n    pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'numpy>=1.10,<1.20' \\\n                'scipy~=1.5.0' \\\n                'scikit-learn~=0.24.1' \\\n                'xgboost~=1.4.0' \\\n                'lightgbm~=3.2.0' \\\n                'dask~=2021.10.0' \\\n                'distributed~=2021.10.0' \\\n                'dask-ml~=2021.10.17' \\\n                'adlfs~=0.7.0' \\\n                'ipykernel~=6.0' \\\n                'azureml-core==1.45.0' \\\n                'azureml-defaults==1.45.0' \\\n                'azureml-mlflow==1.45.0' \\\n                'azureml-telemetry==1.45.0'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH", 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04', 'status': 'Completed', 'startTimeUtc': '2022-10-27T13:39:51.100008Z', 'endTimeUtc': '2022-10-27T13:46:31.154265Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{"learning_rate":"0.5"}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun', 'stages': '{"Initialization":null,"Execution":{"StartTime":"2022-10-27T13:39:51.4838824+00:00","EndTime":"2022-10-27T13:46:31.0588859+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://eymlws6928330879.blob.core.windows.net/azureml/ExperimentRun/dcid.5f85466f-1b84-40ae-ad01-2cf7a9d9cc04/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=BbJV9QcPrrvg66OtJ%2FCnxOuQ0TKeKlIwqBUo%2FUZd9vQ%3D&skoid=b14fdef8-1157-4ffc-b3de-cc465bb262d6&sktid=bdf67597-3a9e-4e19-958e-1d8222afa3de&skt=2022-10-27T13%3A29%3A51Z&ske=2022-10-28T21%3A39%3A51Z&sks=b&skv=2019-07-07&st=2022-10-27T13%3A36%3A32Z&se=2022-10-27T21%3A46%3A32Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://eymlws6928330879.blob.core.windows.net/azureml/ExperimentRun/dcid.5f85466f-1b84-40ae-ad01-2cf7a9d9cc04/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Gu8NPYddEP7Em3ng2u5Ll9Sulw2ZpmD3WWTXC2vx70Q%3D&skoid=b14fdef8-1157-4ffc-b3de-cc465bb262d6&sktid=bdf67597-3a9e-4e19-958e-1d8222afa3de&skt=2022-10-27T13%3A29%3A51Z&ske=2022-10-28T21%3A39%3A51Z&sks=b&skv=2019-07-07&st=2022-10-27T13%3A36%3A32Z&se=2022-10-27T21%3A46%3A32Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://eymlws6928330879.blob.core.windows.net/azureml/ExperimentRun/dcid.5f85466f-1b84-40ae-ad01-2cf7a9d9cc04/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=KZ%2F0fPcRlnS%2Fr2CEdGLJlJc0IdOfI80qsNJUgRJhORc%3D&skoid=b14fdef8-1157-4ffc-b3de-cc465bb262d6&sktid=bdf67597-3a9e-4e19-958e-1d8222afa3de&skt=2022-10-27T13%3A29%3A51Z&ske=2022-10-28T21%3A39%3A51Z&sks=b&skv=2019-07-07&st=2022-10-27T13%3A36%3A32Z&se=2022-10-27T21%3A46%3A32Z&sp=r'}, 'submittedBy': 'Trainer MlOps'}
# 'Finished'

# %% [markdown]
# Suppose you try to rerun the pipeline by executing the code you wrote in previous steps for
# a second time. In that case, you will notice that the execution will be almost instant (just
# a few seconds compared to the minute-long execution you should have seen the first
# time). The pipeline detected that no input had changed and reused the outputs of the
# previously executed steps. This demonstrates what the allow_reuse=True
# does, and it also proves that even though we didn't specify that parameter, the
# default value is True. This means that, by default, all steps will reuse previous executions
# if the inputs and the code files are the same as the ones of an earlier execution. If you want
# to force a retrain even if the same learning_rate variable is passed to the pipeline,
# you can specify allow_reuse=False

# %% [markdown]
# ## Please Note :
# If you wanted to pass the training dataset as a PipelineParameter,
# you would have to use the following code:
#
# from azureml.data.dataset_consumption_config
# import DatasetConsumptionConfig
#
# ds_pipeline_param =
# PipelineParameter(name="dataset ", default_
# value=loans_ds)
#
# dataset_consumption = DatasetConsumptionConfig("loans", ds_pipeline_param)
#
# Using this code and passing the dataset_consumption object
# instead of loans_ds.as_named_input('loans') would allow
# you to select the input dataset and its version while submitting a pipeline
# to execute.

# %% [markdown]
# ## So far, you have defined a pipeline that executes two Python scripts. step_01
# pre-processes the training data and stores it in an intermediate data store for step_02
# to pick up. From there, the second step trains a LightGBM model and stores it in the /
# models/loans/ folder of the default datastore attached to the AzureML workspace.

# %% [markdown]
# ## Troubleshooting code issues
#
# What happens if a script has a coding issue
# or if a dependency is missing? In that case, your pipeline will fail. In the graphical
# representation you saw in experiment, you will be able to identify the failing step. If you
# want to get the details of a specific child step, you will have to first locate it using find_
# step_run of the pipeline_run object you got when you executed the pipeline.

# %%
train_step_run = pipeline_run.find_step_run("Train model")[0]
train_step_run.get_details_with_logs()
# Out:
# {'runId': '550eedd7-8aab-43c5-8a9c-4c0e3092088a',
#  'target': 'akt-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-10-27T13:46:12.137293Z',
#  'endTimeUtc': '2022-10-27T13:46:29.833216Z',
#  'services': {},
#  'properties': {'ContentSnapshotId': '94d70895-9222-4018-bdbc-2cb13af3f02d',
#   'StepType': 'PythonScriptStep',
#   'ComputeTargetType': 'AmlCompute',
#   'azureml.moduleid': '5d3ab1b2-c8c8-46ba-8e44-7dba9768b2f2',
#   'azureml.moduleName': 'Train model',
#   'azureml.runsource': 'azureml.StepRun',
#   'azureml.nodeid': 'd6fb068c',
#   'azureml.pipelinerunid': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04',
#   'azureml.pipeline': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04',
#   'azureml.pipelineComponent': 'masterescloud',
#   '_azureml.ComputeTargetType': 'amlctrain',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [{'identifier': {'savedId': '7d23aeb9-c3ea-4983-b7cb-1135cd7a896e'},
#    'outputType': 'RunOutput',
#    'outputDetails': {'outputName': 'model_store'},
#    'dataset': {
#      "source": [
#        "('workspaceblobstore', 'models/loans/')"
#      ],
#      "definition": [
#        "GetDatastoreFiles"
#      ],
#      "registration": {
#        "id": "7d23aeb9-c3ea-4983-b7cb-1135cd7a896e",
#        "name": null,
#        "version": null,
#        "workspace": "Workspace.create(name='eymlws', subscription_id='afe91b36-9760-4bb8-9dd6-72761af8d4ef', resource_group='eymlops')"
#      }
#    }}],
#  'runDefinition': {'script': 'train_model.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--learning-rate',
#    '$AML_PARAMETER_learning_rate',
#    '--input-path',
#    '$AZUREML_DATAREFERENCE_training_data',
#    '--output-path',
#    'DatasetOutputConfig:model_store'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'akt-cluster',
#   'dataReferences': {'training_data': {'dataStoreName': 'workspaceblobstore',
#     'mode': 'Mount',
#     'pathOnDataStore': 'azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'data': {},
#   'outputData': {'model_store': {'outputLocation': {'dataset': None,
#      'dataPath': {'datastoreName': 'workspaceblobstore',
#       'relativePath': '/models/loans/'},
#      'uri': None,
#      'type': None},
#     'mechanism': 'Mount',
#     'additionalOptions': {'pathOnCompute': None,
#      'registrationOptions': {'name': None,
#       'description': None,
#       'tags': None,
#       'properties': {'azureml.pipelineRunId': '5f85466f-1b84-40ae-ad01-2cf7a9d9cc04',
#        'azureml.pipelineRun.moduleNodeId': 'd6fb068c',
#        'azureml.pipelineRun.outputPortName': 'model_store'},
#       'datasetRegistrationOptions': {'additionalTransformation': None}},
#      'uploadOptions': {'overwrite': False,
#       'sourceGlobs': {'globPatterns': None}},
#      'mountOptions': None},
#     'environmentVariableName': None}},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu',
#    'version': '46',
#    'assetId': 'azureml://registries/azureml/environments/AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu/versions/46',
#    'autoRebuild': True,
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': True,
#     'condaDependencies': None,
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': None,
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': "FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220902.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/lightgbm\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 pip=20.2.4\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\n    pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'numpy>=1.10,<1.20' \\\n                'scipy~=1.5.0' \\\n                'scikit-learn~=0.24.1' \\\n                'xgboost~=1.4.0' \\\n                'lightgbm~=3.2.0' \\\n                'dask~=2021.10.0' \\\n                'distributed~=2021.10.0' \\\n                'dask-ml~=2021.10.17' \\\n                'adlfs~=0.7.0' \\\n                'ipykernel~=6.0' \\\n                'azureml-core==1.45.0' \\\n                'azureml-defaults==1.45.0' \\\n                'azureml-mlflow==1.45.0' \\\n                'azureml-telemetry==1.45.0'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH",
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {'AML_PARAMETER_learning_rate': '0.5'},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'logs/azureml/executionlogs.txt': '[2022-10-27 13:45:56Z] ReuseHash: 145397c0-24a9-473c-8612-65de7db073b7B+OEThVh9GlkteuwhSlNAvGvOvC+CiCJ7pR7mHRyOlU=, JobDefinitionToHash: {"Configuration":{"Script":"train_model.py","Command":"","UseAbsolutePath":false,"Arguments":["--learning-rate","$AML_PARAMETER_learning_rate","--input-path","$AZUREML_DATAREFERENCE_training_data","--output-path","DatasetOutputConfig:model_store"],"Framework":"Python","Communicator":"None","Target":"akt-cluster","DataReferences":{"keys":["training_data"],"values":[{"DataStoreName":"workspaceblobstore","Mode":"Mount","PathOnDataStore":"azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data","Overwrite":false}]},"OutputData":{"keys":["model_store"],"values":[{"OutputLocation":{"DataPath":{"DatastoreName":"workspaceblobstore","RelativePath":"/models/loans/"}},"Mechanism":"Mount","AdditionalOptions":{"UploadOptions":{"Overwrite":false}}}]},"NodeCount":1,"CredentialPassthrough":false,"Environment":{"Name":"AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu","Version":"46","Python":{"InterpreterPath":"python","UserManagedDependencies":true},"EnvironmentVariables":{"EXAMPLE_ENV_VAR":"EXAMPLE_VALUE"},"Docker":{"Platform":{"Os":"Linux","Architecture":"amd64"},"BaseDockerfile":"FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220902.v1\\n\\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/lightgbm\\n# Create conda environment\\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\\\\n    python=3.7 pip=20.2.4\\n\\n# Prepend path to AzureML conda environment\\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\\n\\n# Install pip dependencies\\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\\\\n    pip install \'matplotlib>=3.3,<3.4\' \\\\\\n                \'psutil>=5.8,<5.9\' \\\\\\n                \'tqdm>=4.59,<4.60\' \\\\\\n                \'pandas>=1.1,<1.2\' \\\\\\n                \'numpy>=1.10,<1.20\' \\\\\\n                \'scipy~=1.5.0\' \\\\\\n                \'scikit-learn~=0.24.1\' \\\\\\n                \'xgboost~=1.4.0\' \\\\\\n                \'lightgbm~=3.2.0\' \\\\\\n                \'dask~=2021.10.0\' \\\\\\n                \'distributed~=2021.10.0\' \\\\\\n                \'dask-ml~=2021.10.17\' \\\\\\n                \'adlfs~=0.7.0\' \\\\\\n                \'ipykernel~=6.0\' \\\\\\n                \'azureml-core==1.45.0\' \\\\\\n                \'azureml-defaults==1.45.0\' \\\\\\n                \'azureml-mlflow==1.45.0\' \\\\\\n                \'azureml-telemetry==1.45.0\'\\n\\n# This is needed for mpi to locate libpython\\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH","Enabled":false},"Spark":{"PrecachePackages":true}},"History":{"OutputCollection":true,"DirectoriesToWatch":["logs"],"EnableMLflowTracking":true},"Spark":{"Configuration":{"spark.app.name":"Azure ML Experiment","spark.yarn.maxAppAttempts":"1"}},"ParallelTask":{"MaxRetriesPerWorker":0,"WorkerCountPerNode":1},"BatchAi":{"NodeCount":0},"AmlCompute":{"RetainCluster":false,"ClusterMaxNodeCount":1},"AISuperComputer":{"InstanceType":"D2","ImageVersion":"pytorch-1.7.0","Interactive":false,"EnableAzmlInt":true,"SLATier":"Standard"},"Tensorflow":{"WorkerCount":1,"ParameterServerCount":1},"Mpi":{"ProcessCountPerNode":1},"PyTorch":{"CommunicationBackend":"nccl"},"Hdi":{"YarnDeployMode":"Cluster"},"ContainerInstance":{"CpuCores":2.0,"MemoryGb":3.5},"Docker":{"UseDocker":false,"SharedVolumes":true,"ShmSize":"2g"},"CommandReturnCodeConfig":{"ReturnCode":"Zero"},"EnvironmentVariables":{"AML_PARAMETER_learning_rate":"0.5"}},"SnapshotId":"94d70895-9222-4018-bdbc-2cb13af3f02d"}\n[2022-10-27 13:45:56Z] Starting run in Execution Service\n[2022-10-27 13:45:56Z] RunId:[550eedd7-8aab-43c5-8a9c-4c0e3092088a] ParentRunId:[5f85466f-1b84-40ae-ad01-2cf7a9d9cc04] ComputeTarget:[AmlCompute]\n[2022-10-27 13:45:57Z] Job is in progress. Execution status: Preparing.\n[2022-10-27 13:45:58Z] Job is in progress. Execution status: Queued.\n[2022-10-27 13:45:59Z] Job is in progress. Execut ...
#   'logs/azureml/stderrlogs.txt': '',
#   'logs/azureml/stdoutlogs.txt': '',
#   'user_logs/std_log.txt': "Loading data from /mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/data-capability/wd/INPUT_training_data_workspaceblobstore/azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data\n[LightGBM] [Info] Load from binary file /mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/data-capability/wd/INPUT_training_data_workspaceblobstore/azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data/train_dataset.bin\n[LightGBM] [Info] Number of positive: 119, number of negative: 281\n[LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000051 seconds.\nYou can set `force_col_wise=true` to remove the overhead.\n[LightGBM] [Info] Total Bins 190\n[LightGBM] [Info] Number of data points in the train set: 400, number of used features: 3\n[LightGBM] [Info] [binary:BoostFromScore]: pavg=0.297500 -> initscore=-0.859231\n[LightGBM] [Info] Start training from score -0.859231\n[1]\tvalid_0's auc: 0.94381\nTraining until validation scores don't improve for 5 rounds\n[2]\tvalid_0's auc: 0.94619\n[3]\tvalid_0's auc: 0.952619\n[4]\tvalid_0's auc: 0.959524\n[5]\tvalid_0's auc: 0.959048\n[6]\tvalid_0's auc: 0.950238\n[7]\tvalid_0's auc: 0.950476\n[8]\tvalid_0's auc: 0.940714\n[9]\tvalid_0's auc: 0.940714\nEarly stopping, best iteration is:\n[4]\tvalid_0's auc: 0.959524\nCleaning up all outstanding Run operations, waiting 300.0 seconds\n1 items cleaning up...\nCleanup took 0.06443548202514648 seconds\n",
#   'system_logs/cs_capability/cs-capability.log': 'INFO 2022-10-27 13:46:14,089 initializer.py:59 [1] - job_telemetry_init {\'artifact_type\': \'installed\', \'ci_number\': \'20221025.3\', \'ci_name\': \'CommonRuntime-prod-build\', \'build_time\': \'2022-10-25 17:29:38.324760\', \'subscription_id\': \'afe91b36-9760-4bb8-9dd6-72761af8d4ef\', \'resource_group\': \'eymlops\', \'workspace_name\': \'eymlws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'pipeline_exp\', \'node_rank\': \'None\', \'node_id\': \'tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d\', \'root_run_id\': \'5f85466f-1b84-40ae-ad01-2cf7a9d9cc04\', \'run_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'correlation_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'4b14d841-e275-421e-941a-84c0706d208d\', \'version\': \'0.0.1.20221025.3\', \'commit\': \'1466aec\', \'branch\': \'origin/1466aec166fb4472f6e270c7c5c63c31b99129bb\', \'os\': \'linux\', \'custom_dimensions\': {\'artifact_type\': \'installed\', \'ci_number\': \'20221025.3\', \'ci_name\': \'CommonRuntime-prod-build\', \'build_time\': \'2022-10-25 17:29:38.324760\', \'subscription_id\': \'afe91b36-9760-4bb8-9dd6-72761af8d4ef\', \'resource_group\': \'eymlops\', \'workspace_name\': \'eymlws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'pipeline_exp\', \'node_rank\': \'None\', \'node_id\': \'tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d\', \'root_run_id\': \'5f85466f-1b84-40ae-ad01-2cf7a9d9cc04\', \'run_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'correlation_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'4b14d841-e275-421e-941a-84c0706d208d\', \'version\': \'0.0.1.20221025.3\', \'commit\': \'1466aec\', \'branch\': \'origin/1466aec166fb4472f6e270c7c5c63c31b99129bb\', \'os\': \'linux\'}}\nINFO 2022-10-27 13:46:14,089 tracer.py:32 [1] - Setting up tracer {\'component_name\': \'cs-capability\', \'telemetry_config\': \'{"collector": {"receiver": null, "exporter": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e"}, "jaeger": null, "prometheus": null, "timeout_millis": null, "level": null}}, "logger": {"console": null, "appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e", "level": "info", "enabled": true}, "file": {"extension": "log", "level": "info", "enabled": true}}, "node_rank": null, "node_id": "tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d", "disable_sensitive_scrub": null}\', \'subscription_id\': \'afe91b36-9760-4bb8-9dd6-72761af8d4ef\', \'resource_group\': \'eymlops\', \'workspace_name\': \'eymlws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'pipeline_exp\', \'node_rank\': \'None\', \'node_id\': \'tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d\', \'root_run_id\': \'5f85466f-1b84-40ae-ad01-2cf7a9d9cc04\', \'run_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'correlation_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'4b14d841-e275-421e-941a-84c0706d208d\', \'version\': \'0.0.1.20221025.3\', \'commit\': \'1466aec\', \'branch\': \'origin/1466aec166fb4472f6e270c7c5c63c31b99129bb\', \'os\': \'linux\', \'custom_dimensions\': {\'component_name\': \'cs-capability\', \'telemetry_config\': \'{"collector": {"receiver": null, "exporter": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e"}, "jaeger": null, "prometheus": null, "timeout_millis": null, "level": null}}, "logger": {"console": null, "appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e", "level": "info", "enabled": true}, "file": {"extension": "log", "level": "info", "enabled": true}}, "node_rank": null, "node_id": "tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d", "disable_sensitive_scrub": n ...
#   'system_logs/data_capability/data-capability.log': 'INFO 2022-10-27 13:46:16,181 initializer.py:59 [32] - job_telemetry_init {\'artifact_type\': \'installed\', \'ci_number\': \'20221025.3\', \'ci_name\': \'CommonRuntime-prod-build\', \'build_time\': \'2022-10-25 17:29:38.093954\', \'subscription_id\': \'afe91b36-9760-4bb8-9dd6-72761af8d4ef\', \'resource_group\': \'eymlops\', \'workspace_name\': \'eymlws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'pipeline_exp\', \'node_rank\': \'None\', \'node_id\': \'tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d\', \'root_run_id\': \'5f85466f-1b84-40ae-ad01-2cf7a9d9cc04\', \'run_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'correlation_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'source\': \'common_runtime.data-capability\', \'session_id\': \'775fe486-710a-4be8-8856-bfd8a2068650\', \'version\': \'0.0.1.20221025.3\', \'commit\': \'1466aec\', \'branch\': \'origin/1466aec166fb4472f6e270c7c5c63c31b99129bb\', \'os\': \'linux\', \'custom_dimensions\': {\'artifact_type\': \'installed\', \'ci_number\': \'20221025.3\', \'ci_name\': \'CommonRuntime-prod-build\', \'build_time\': \'2022-10-25 17:29:38.093954\', \'subscription_id\': \'afe91b36-9760-4bb8-9dd6-72761af8d4ef\', \'resource_group\': \'eymlops\', \'workspace_name\': \'eymlws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'pipeline_exp\', \'node_rank\': \'None\', \'node_id\': \'tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d\', \'root_run_id\': \'5f85466f-1b84-40ae-ad01-2cf7a9d9cc04\', \'run_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'correlation_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'source\': \'common_runtime.data-capability\', \'session_id\': \'775fe486-710a-4be8-8856-bfd8a2068650\', \'version\': \'0.0.1.20221025.3\', \'commit\': \'1466aec\', \'branch\': \'origin/1466aec166fb4472f6e270c7c5c63c31b99129bb\', \'os\': \'linux\'}}\nINFO 2022-10-27 13:46:16,181 tracer.py:32 [32] - Setting up tracer {\'component_name\': \'data-capability\', \'telemetry_config\': \'{"collector": {"receiver": null, "exporter": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e"}, "jaeger": null, "prometheus": null, "timeout_millis": null, "level": null}}, "logger": {"console": null, "appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e", "level": "info", "enabled": true}, "file": {"extension": "log", "level": "info", "enabled": true}}, "node_rank": null, "node_id": "tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d", "disable_sensitive_scrub": null}\', \'subscription_id\': \'afe91b36-9760-4bb8-9dd6-72761af8d4ef\', \'resource_group\': \'eymlops\', \'workspace_name\': \'eymlws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'pipeline_exp\', \'node_rank\': \'None\', \'node_id\': \'tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d\', \'root_run_id\': \'5f85466f-1b84-40ae-ad01-2cf7a9d9cc04\', \'run_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'correlation_id\': \'550eedd7-8aab-43c5-8a9c-4c0e3092088a\', \'source\': \'common_runtime.data-capability\', \'session_id\': \'775fe486-710a-4be8-8856-bfd8a2068650\', \'version\': \'0.0.1.20221025.3\', \'commit\': \'1466aec\', \'branch\': \'origin/1466aec166fb4472f6e270c7c5c63c31b99129bb\', \'os\': \'linux\', \'custom_dimensions\': {\'component_name\': \'data-capability\', \'telemetry_config\': \'{"collector": {"receiver": null, "exporter": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e"}, "jaeger": null, "prometheus": null, "timeout_millis": null, "level": null}}, "logger": {"console": null, "appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e", "level": "info", "enabled": true}, "file": {"extension": "log", "level": "info", "enabled": true}}, "node_rank": null, "node_id": "tvmps_c7cb529b69955cefd8a06853dfe427c16ad522de65d621bc6c662be4c6696c29_d", "disable_sen ...
#   'system_logs/data_capability/rslex.log.2022-10-27-13': '2022-10-27T13:46:17.163935Z  INFO rslex_fuse::direct_volume_mount::options: [rslex-fuse::DirectVolumeOptions] Environment variable "DATASET_MOUNT_BLOCK_BASED_CACHE_ENABLED" has been set to true env_variable_name="DATASET_MOUNT_BLOCK_BASED_CACHE_ENABLED" env_variable_value=true descriptor="rslex-fuse::DirectVolumeOptions::config_env_set"\n2022-10-27T13:46:17.289702Z  INFO rslex_azureml::data_store::resolver: [CachedResolver::resolve()] datastore resolved datastore_name=Some("workspaceblobstore") datastore_type=Some(AzureBlob)\n2022-10-27T13:46:17.313842Z  WARN rslex_http_stream::http_service_client::error_mapped_http_service_client: [rslex-http-stream::http_service_client] non-successful response host=eymlws6928330879.blob.core.windows.net method=HEAD error=HttpServiceError { service: "azure_blob", inner_error: The specified blob does not exist. } service_request_id=Some("5d9fba2f-c01e-0031-1c0a-eaa31e000000")\n2022-10-27T13:46:17.318544Z  WARN rslex_fuse::direct_volume_mount::direct_volume_mount: [rslex-fuse::direct-volume-mount::new()] read write path not found, try to create. mount_point=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/data-capability/wd/model_store\n2022-10-27T13:46:17.349262Z  INFO rslex_fuse::direct_volume_mount::direct_volume_mount: [rslex-fuse::DirectVolumeMount::new()] Direct volume mount created. mount_point=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/data-capability/wd/model_store handler=AmlDatastore options=DirectVolumeOptions { is_single_file: None, default_permission: Some(511), attribute_cache_entry_ttl: 18446744073709551615.999999999s, disk_cache_options: DiskCacheOptions { cache_dir_path: None, reserved_free_disk_space: 157286400, cache_limit: Unlimited, prune_threshold: 1.0, prune_target: 0.7, _cache_resources_phantom: PhantomData }, streaming_read_options: StreamingReadOptions { block_size: 2097152, buffered_blocks_count: 32, reading_threads: 32 }, block_based_reading_options: Some(BlockBasedReadingOptions { memory_cache_options: Some(MemoryCacheOptions { cache_size: 134217728 }), file_cache_options: Some(BlockBasedFileCacheWriteOptions { pending_writes_queue_size: 536870912, writer_threads: 16 }) }), mount_mode: CreateAndWrite }\n2022-10-27T13:46:17.349461Z  INFO new{options=MountOptions { allow_other: true, fuse_cache_timeout: 600s, unmount_timeout: 30s }}: rslex_fuse::fuse_fs::fuse_mount: close time.busy=18.8µs time.idle=22.8µs\n2022-10-27T13:46:17.350053Z  INFO rslex_fuse::fuse_fs::fuse_mount: [rslex-fuse::FuseMount::mount] mounting filesystem with mount arguments ["dataset_volume_mount", "-o", "allow_other", "-o", "attr_timeout=0", "-o", "entry_timeout=600", "-o", "big_writes", "-o", "fsname=rslex_volume_mount[AmlDatastore]"]. Libfuse version 29 fuse_arguments=["dataset_volume_mount", "-o", "allow_other", "-o", "attr_timeout=0", "-o", "entry_timeout=600", "-o", "big_writes", "-o", "fsname=rslex_volume_mount[AmlDatastore]"] fuse_version=29 pid=32 mount_point=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/data-capability/wd/model_store\n2022-10-27T13:46:18.350715Z  INFO rslex_fuse::fuse_fs::fuse_mount: [rslex-fuse::FuseMount::mount] filesystem mounted pid=32 mount_point=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/data-capability/wd/model_store\n2022-10-27T13:46:25.272990Z  WARN rslex_http_stream::http_service_client::error_mapped_http_service_client: [rslex-http-stream::http_service_client] non-successful response host=eymlws6928330879.blob.core.windows.net method=HEAD error=HttpServiceError { service: "azure_blob", inner_error: The specified blob does not exist. } service_request_id=Some("5d9febae-c01e-0031-120a-eaa31e000000")\n2022-10-27T13:46:25.344578Z  INFO copy:do_sequential_copy{file_size=6138}: rslex_core::file_io::stream_copier: close time.busy=9.60ms time.idle=3.40µs\n2022-10-27T13:46:25.344611Z  INFO copy: rslex_core::file_io::stream_copier: [StreamCopier::copy()] copied file size=6138 ...
#   'system_logs/hosttools_capability/hosttools-capability.log': '2022-10-27T13:46:12.596994Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/1466aec166fb4472f6e270c7c5c63c31b99129bb ci_number=20221025.3 ci_name=CommonRuntime-prod-build build_time=2022-10-25 17:30:07.762336\n2022-10-27T13:46:12.597167Z  INFO hosttools-capability::do_main: hosttools_capability::resource_limit: Current limit for number of open file: soft=262144, hard=262144 soft_limit=262144 hard_limit=262144\n2022-10-27T13:46:12.597576Z  INFO hosttools-capability::do_main: cr_core: Successfully configured current process to ignore termination signals\n2022-10-27T13:46:12.597602Z  INFO hosttools-capability::do_main: hosttools_capability: Hosttools cap config ht_cap_config={"dirs":[{"relative_path":"user_logs","environment_name":"AZUREML_CR_HT_CAP_user_logs_PATH","streamable":true},{"relative_path":"azureml-logs","environment_name":"AZUREML_CR_HT_CAP_azureml_logs_PATH","streamable":true},{"relative_path":"outputs","environment_name":"AZUREML_CR_HT_CAP_outputs_PATH","streamable":false},{"relative_path":"logs","environment_name":"AZUREML_CR_HT_CAP_logs_PATH","streamable":true}],"metrics":{"enabled":false,"polling_interval_sec":30,"send_to_history_interval_sec":60},"use_block_blob_in_blob_streamer":true,"log_filtering_policy":null}\n2022-10-27T13:46:12.597688Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config: cr_core::config_parser: Failed to get distributed config from env exception=GetEnvVarFailed("AZUREML_CR_DISTRIBUTED_CONFIG")\n2022-10-27T13:46:12.597867Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config: hosttools_capability::config_parser: appinsights instrumentation key is set in telemetry config\n2022-10-27T13:46:12.597951Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config:hosttools-capability.add_cert_env_vars_from_file{path="/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/hosttools-capability/wd/cert_info.txt"}: hosttools_capability::config_parser: Cert envs from cert_file was successful\n2022-10-27T13:46:12.597965Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config:hosttools-capability.add_cert_env_vars_from_file{path="/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/cap/hosttools-capability/wd/cert_info.txt"}: hosttools_capability::config_parser: close time.busy=61.9µs time.idle=9.60µs\n2022-10-27T13:46:12.598015Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config: hosttools_capability::config_parser: close time.busy=387µs time.idle=8.10µs\n2022-10-27T13:46:12.599820Z  INFO hosttools-capability::do_main:hosttools-capability.start_hosttools{task="outputManager"}: hosttools_capability::hosttools: child spawned child=Child { child: Child(ChildDropGuard { inner: Child { pid: 10 }, kill_on_drop: false }), stdin: None, stdout: Some(ChildStdout { inner: PollEvented { io: Some(Pipe { fd: File { fd: 10, path: "pipe:[46600]", read: true, write: false } }) } }), stderr: Some(ChildStderr { inner: PollEvented { io: Some(Pipe { fd: File { fd: 12, path: "pipe:[46601]", read: true, write: false } }) } }) }\n2022-10-27T13:46:12.599982Z  INFO hosttools-capability::do_main:hosttools-capability.start_hosttools{task="outputManager"}: hosttools_capability::hosttools: close time.busy=1.83ms time.idle=4.00µs\n2022-10-27T13:46:12.600033Z  INFO hosttools-capability::do_main: hosttools_capability: Starting gRPC server at server_addr=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/hosttools-capability:0\n2022-10-27T13:46:12.600049Z  INFO hosttools-capability::do_main: hosttools_capability::service: serving capability service at address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/hosttools-capability:0\n2022-10-27T13:46:12.600173Z  INFO hosttools-capability::do_main:serve: grpc_utils::endpoint::serve: serving gRPC service endpoint=Uds("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/hosttools-capability:0") retry=Exponent ...
#   'system_logs/lifecycler/execution-wrapper.log': '2022-10-27T13:46:13.338292Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/1466aec166fb4472f6e270c7c5c63c31b99129bb ci_number=20221025.3 ci_name=CommonRuntime-prod-build build_time=2022-10-25 17:29:17.929519\n2022-10-27T13:46:13.343184Z  INFO run_execution_wrapper: execution_wrapper: Successfully dumped bootstrapping environment to file\n2022-10-27T13:46:13.343212Z  INFO run_execution_wrapper: execution_wrapper: Enable std log streaming is not specified in executor configuration, default to not stream logs to stdout and stderr\n2022-10-27T13:46:13.343224Z  INFO run_execution_wrapper: execution_wrapper: Enable termination signal handling is not specified in executor configuration, default to ignore termination signals\n2022-10-27T13:46:13.343292Z  INFO run_execution_wrapper:execution-wrapper::run_service{executor_config=ExecutorConfig { execution_working_dir: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/exe/wd", executor_address: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/executor:0", lifecycler_address: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0", distributed_config: None, use_mpi_rsh_agent: Some(true), executor_config: None } path_mapping_kind=None enable_std_log_streaming=false enable_termination_signal_handling=false env_dump_result=Ok(())}: execution_wrapper::service: serving execution service at executor_address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/executor:0\n2022-10-27T13:46:13.343555Z  INFO run_execution_wrapper:execution-wrapper::run_service{executor_config=ExecutorConfig { execution_working_dir: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/exe/wd", executor_address: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/executor:0", lifecycler_address: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0", distributed_config: None, use_mpi_rsh_agent: Some(true), executor_config: None } path_mapping_kind=None enable_std_log_streaming=false enable_termination_signal_handling=false env_dump_result=Ok(())}: cr_core: Successfully configured current process to ignore termination signals\n2022-10-27T13:46:13.343592Z  INFO run_execution_wrapper:execution-wrapper::run_service{executor_config=ExecutorConfig { execution_working_dir: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/exe/wd", executor_address: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/executor:0", lifecycler_address: "/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0", distributed_config: None, use_mpi_rsh_agent: Some(true), executor_config: None } path_mapping_kind=None enable_std_log_streaming=false enable_termination_signal_handling=false env_dump_result=Ok(())}:serve: grpc_utils::endpoint::serve: serving gRPC service endpoint=Uds("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/executor:0") retry=ExponentialBackoffRetry { retry_delay_secs: 2, delay_factor: 1000, num_retries: 3 }\n2022-10-27T13:46:20.484333Z  INFO ExecutionServicer::run: grpc_utils::server: Got grpc request request_name="run" remote_addr=None\n2022-10-27T13:46:20.484416Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{error_detector=Some(ErrorDetector { errors: Mutex { data: [] } }) finalization=ExecutionFinalizer { execution_id: "1457be62-b21e-4651-b526-ab0065d90f4f", client_address: Some("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0") }}: execution_wrapper::service: spawn_execution request id="1457be62-b21e-4651-b526-ab0065d90f4f" client_address=Some("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0")\n2022-10-27T13:46:20.484452Z  WARN ExecutionServicer::run:ExecutionServicer::spawn_execution{error_detector=Some(ErrorDetector { errors: Mutex { data: [] } }) finalization=ExecutionFinalizer { execution_id: "1457be62-b21e-4651-b526-ab0065d90f4f", client_address: Some("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859 ...
#   'system_logs/lifecycler/lifecycler.log': '2022-10-27T13:46:13.098360Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/1466aec166fb4472f6e270c7c5c63c31b99129bb ci_number=20221025.3 ci_name=CommonRuntime-prod-build build_time=2022-10-25 17:31:48.023642\n2022-10-27T13:46:13.101051Z  INFO load_config_from_env: lifecycler::config: Resolved grpc addresses lifecycler_address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0 executor_address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/executor:0\n2022-10-27T13:46:13.101255Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for DATA_CAPABILITY cap_name=DATA_CAPABILITY address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/data-capability:0\n2022-10-27T13:46:13.101312Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for SNAPSHOT_CAPABILITY cap_name=SNAPSHOT_CAPABILITY address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/snapshot-capability:0\n2022-10-27T13:46:13.101352Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for CS_CAPABILITY cap_name=CS_CAPABILITY address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/cs-capability:0\n2022-10-27T13:46:13.101388Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for HOSTTOOLS_CAPABILITY cap_name=HOSTTOOLS_CAPABILITY address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/hosttools-capability:0\n2022-10-27T13:46:13.101423Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for METRICS_CAPABILITY cap_name=METRICS_CAPABILITY address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/metrics-capability:0\n2022-10-27T13:46:13.101468Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: close time.busy=348µs time.idle=6.20µs\n2022-10-27T13:46:13.101547Z  INFO load_config_from_env: lifecycler::config: close time.busy=656µs time.idle=16.5µs\n2022-10-27T13:46:13.101644Z  INFO run_lifecycler:run_service_and_step_through_lifecycle: lifecycler::lifecycle: distributed config is not specified, skip setting up distributed barrier\n2022-10-27T13:46:13.101890Z  INFO Lifecycler::run_service{distributed_state_sender=None}: lifecycler::service: serving lifecycle service address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0\n2022-10-27T13:46:13.102046Z  INFO Lifecycler::run_service{distributed_state_sender=None}:serve_more: grpc_utils::endpoint::serve: serving gRPC service endpoint=Uds("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/lifecycler:0") retry=ExponentialBackoffRetry { retry_delay_secs: 2, delay_factor: 1000, num_retries: 3 }\n2022-10-27T13:46:13.103051Z  INFO run_lifecycler:run_service_and_step_through_lifecycle: lifecycler::lifecycle: Trying to configure lifecycler to ignore termination signals\n2022-10-27T13:46:13.103179Z  INFO run_lifecycler:run_service_and_step_through_lifecycle: cr_core: Successfully configured current process to ignore termination signals\n2022-10-27T13:46:13.103378Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: Connecting to gRPC service endpoint=Uds("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/data-capability:0") retry=FixedIntervalRetry { attempt_timeout_millis: 50, retry_delay_millis: 10, max_duration: 86400s }\n2022-10-27T13:46:16.235387Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: Successfully connected to gRPC service endpoint=Uds("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/data-capability:0")\n2022-10-27T13:46:16.235487Z  INFO run_lifecycler: ...
#   'system_logs/metrics_capability/metrics-capability.log': '2022-10-27T13:46:13.030158Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/1466aec166fb4472f6e270c7c5c63c31b99129bb ci_number=20221025.3 ci_name=CommonRuntime-prod-build build_time=2022-10-25 17:29:17.574142\n2022-10-27T13:46:13.037400Z  INFO metrics-capability::do_main: metrics_capability: metrics cap config cap_config=MetricsCapConfig { polling_interval_sec: 15, send_to_history_interval_sec: 60, enabled_resource_metrics: ["CpuUtilizationPercentage", "GpuUtilizationPercentage", "GpuEnergyJoules", "GpuMemoryUtilizationPercentage", "GpuMemoryUtilizationMegabytes", "GpuMemoryCapacityMegabytes", "CpuMemoryUtilizationPercentage", "CpuMemoryUtilizationMegabytes", "CpuMemoryCapacityMegabytes", "DiskReadMegabytes", "DiskWriteMegabytes", "NetworkInputMegabytes", "NetworkOutputMegabytes", "IBReceiveMegabytes", "IBTransmitMegabytes", "DiskUsedMegabytes", "DiskAvailMegabytes"], reserved_disk_space_bytes: 1400000000, additional_scrape_jobs: [] }\n2022-10-27T13:46:13.037675Z  INFO metrics-capability::do_main: metrics_capability: run token file created\n2022-10-27T13:46:13.037748Z  INFO metrics-capability::do_main: metrics_capability: embedded file file="prometheus-template.yml"\n2022-10-27T13:46:13.042690Z  INFO metrics-capability::do_main: metrics_capability: prometheus config file created\n2022-10-27T13:46:13.042877Z  INFO metrics-capability::do_main: metrics_capability::additional_scrape_jobs_configer: No additional scrape jobs configured.\n2022-10-27T13:46:13.043007Z  INFO metrics_capability: starting prometheus subprocess watcher task\n2022-10-27T13:46:13.043032Z  INFO metrics_capability: starting prometheus subprocess: prometheus ["--storage.tsdb.retention.time=30m", "--log.level=info", "--enable-feature=expand-external-labels", "--config.file=/usr/local/bin/prometheus.yml", "--web.listen-address=0.0.0.0:9090"] retry_count=1\n2022-10-27T13:46:13.043167Z  INFO metrics_capability: starting cadvisor subprocess watcher task\n2022-10-27T13:46:13.043187Z  INFO metrics_capability: starting cadvisor subprocess: cadvisor ["--stderrthreshold=0", "--raw_cgroup_prefix_whitelist=/system.slice/containerd.service", "--listen_ip=0.0.0.0", "--port=8081"] retry_count=1\n2022-10-27T13:46:13.043351Z  INFO metrics-capability::do_main: metrics_capability: No GPUs found, skipping nvidia-smi instant exporter\n2022-10-27T13:46:13.043400Z  INFO metrics-capability::do_main: metrics_capability: metrics capability starting service address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/metrics-capability:0\n2022-10-27T13:46:13.043467Z  INFO metrics-capability::do_main:metrics-capability::run_service{address="/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/metrics-capability:0" handles=[JoinHandle { id: Id(7) }, JoinHandle { id: Id(8) }, JoinHandle { id: Id(9) }, JoinHandle { id: Id(10) }, JoinHandle { id: Id(11) }, JoinHandle { id: Id(12) }]}: metrics_capability::service: metrics capability starting service address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/metrics-capability:0\n2022-10-27T13:46:13.043627Z  INFO metrics_capability: started cadvisor subprocess\n2022-10-27T13:46:13.043759Z  INFO metrics_capability: started prometheus subprocess\n2022-10-27T13:46:13.043795Z  INFO metrics_capability: starting node-exporter subprocess watcher task\n2022-10-27T13:46:13.043806Z  INFO metrics_capability: starting node-exporter subprocess: node_exporter ["--collector.disable-defaults", "--collector.infiniband", "--collector.diskstats", "--log.level=info", "--web.listen-address=0.0.0.0:9100"] retry_count=1\n2022-10-27T13:46:13.043810Z  INFO metrics_capability: heartbeat: starting\n2022-10-27T13:46:13.043933Z  INFO metrics-capability::do_main:metrics-capability::run_service{address="/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/metrics-capability:0" handles=[JoinHandle { id: Id(7) }, JoinHandle { id: Id(8) }, JoinHandle { id: Id(9) }, JoinHandle ...
#   'system_logs/snapshot_capability/snapshot-capability.log': '2022-10-27T13:46:13.085955Z  INFO telemetry: job_telemetry_init artifact_type= branch= ci_number= ci_name= build_time=\n2022-10-27T13:46:13.089309Z  INFO snapshot-capability::do_main:snapshot-capability.parse_config: snapshot_capability::config_parser: Initialized config for snapshot download\n2022-10-27T13:46:13.089785Z  INFO snapshot-capability::do_main:snapshot-capability.parse_config: snapshot_capability::config_parser: close time.busy=514µs time.idle=7.00µs\n2022-10-27T13:46:13.089868Z  INFO snapshot-capability::do_main: snapshot_capability: snapshot-capability starting service at server_address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/snapshot-capability:0\n2022-10-27T13:46:13.090920Z  INFO snapshot-capability::do_main:snapshot-capability::run_service{address="/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/snapshot-capability:0" snapshot_cap_config=Ok(SnapshotCapConfig { azureml_context: AzureMLContext { subscription_id: "afe91b36-9760-4bb8-9dd6-72761af8d4ef", resource_group: "eymlops", workspace_name: "eymlws", workspace_id: "145397c0-24a9-473c-8612-65de7db073b7", service_endpoint: "https://eastus.api.azureml.ms", discovery_endpoint: "https://eastus.api.azureml.ms/discovery", experiment_name: "pipeline_exp", experiment_id: "5d3b927e-1efd-4888-a0c1-4c96b893d136", run_id: "550eedd7-8aab-43c5-8a9c-4c0e3092088a", root_run_id: "5f85466f-1b84-40ae-ad01-2cf7a9d9cc04", run_token-length: 1253, run_history_service_endpoint: "https://eastus.api.azureml.ms", data_container_id: "dcid.550eedd7-8aab-43c5-8a9c-4c0e3092088a", run_uuid: "ee6bae35-8091-4954-bb6f-97b969859ecd" }, snapshots: Some([Snapshot { snapshot_asset_id: None, id: Some("94d70895-9222-4018-bdbc-2cb13af3f02d"), path_stack: Some(["."]) }]), user_wd: Some("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/exe/wd"), check_hash: Some(false) })}: snapshot_capability::service: snapshot capability serving at address=/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/snapshot-capability:0\n2022-10-27T13:46:13.091087Z  INFO snapshot-capability::do_main:snapshot-capability::run_service{address="/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/snapshot-capability:0" snapshot_cap_config=Ok(SnapshotCapConfig { azureml_context: AzureMLContext { subscription_id: "afe91b36-9760-4bb8-9dd6-72761af8d4ef", resource_group: "eymlops", workspace_name: "eymlws", workspace_id: "145397c0-24a9-473c-8612-65de7db073b7", service_endpoint: "https://eastus.api.azureml.ms", discovery_endpoint: "https://eastus.api.azureml.ms/discovery", experiment_name: "pipeline_exp", experiment_id: "5d3b927e-1efd-4888-a0c1-4c96b893d136", run_id: "550eedd7-8aab-43c5-8a9c-4c0e3092088a", root_run_id: "5f85466f-1b84-40ae-ad01-2cf7a9d9cc04", run_token-length: 1253, run_history_service_endpoint: "https://eastus.api.azureml.ms", data_container_id: "dcid.550eedd7-8aab-43c5-8a9c-4c0e3092088a", run_uuid: "ee6bae35-8091-4954-bb6f-97b969859ecd" }, snapshots: Some([Snapshot { snapshot_asset_id: None, id: Some("94d70895-9222-4018-bdbc-2cb13af3f02d"), path_stack: Some(["."]) }]), user_wd: Some("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/exe/wd"), check_hash: Some(false) })}:serve: grpc_utils::endpoint::serve: serving gRPC service endpoint=Uds("/mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/.grpc/snapshot-capability:0") retry=ExponentialBackoffRetry { retry_delay_secs: 2, delay_factor: 1000, num_retries: 3 }\n2022-10-27T13:46:16.248124Z  INFO snapshot-capability.start: grpc_utils::server: Got grpc request request_name="start" remote_addr=None\n2022-10-27T13:46:16.248234Z  INFO snapshot-capability.start: snapshot_capability::snapshot_downloader: Using local working directory: /mnt/azureml/cr/j/ee6bae3580914954bb6f97b969859ecd/exe/wd\n2022-10-27T13:46:16.248281Z  INFO snapshot-capability.start: snapshot_capability::snapshot_downloader: Fetching snapshot ID: 94d70895-9222-4018-bdbc-2cb13af3f02d\n2022-10-27T13:46:16.331264Z  ...
#   'STDOUT': '',
#   'STDERR': '',
#   'JOBLOG': '[2022-10-27 13:45:56Z] ReuseHash: 145397c0-24a9-473c-8612-65de7db073b7B+OEThVh9GlkteuwhSlNAvGvOvC+CiCJ7pR7mHRyOlU=, JobDefinitionToHash: {"Configuration":{"Script":"train_model.py","Command":"","UseAbsolutePath":false,"Arguments":["--learning-rate","$AML_PARAMETER_learning_rate","--input-path","$AZUREML_DATAREFERENCE_training_data","--output-path","DatasetOutputConfig:model_store"],"Framework":"Python","Communicator":"None","Target":"akt-cluster","DataReferences":{"keys":["training_data"],"values":[{"DataStoreName":"workspaceblobstore","Mode":"Mount","PathOnDataStore":"azureml/f4aea2da-ed30-4905-b0de-f3093539eb67/training_data","Overwrite":false}]},"OutputData":{"keys":["model_store"],"values":[{"OutputLocation":{"DataPath":{"DatastoreName":"workspaceblobstore","RelativePath":"/models/loans/"}},"Mechanism":"Mount","AdditionalOptions":{"UploadOptions":{"Overwrite":false}}}]},"NodeCount":1,"CredentialPassthrough":false,"Environment":{"Name":"AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu","Version":"46","Python":{"InterpreterPath":"python","UserManagedDependencies":true},"EnvironmentVariables":{"EXAMPLE_ENV_VAR":"EXAMPLE_VALUE"},"Docker":{"Platform":{"Os":"Linux","Architecture":"amd64"},"BaseDockerfile":"FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220902.v1\\n\\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/lightgbm\\n# Create conda environment\\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\\\\n    python=3.7 pip=20.2.4\\n\\n# Prepend path to AzureML conda environment\\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\\n\\n# Install pip dependencies\\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\\\\n    pip install \'matplotlib>=3.3,<3.4\' \\\\\\n                \'psutil>=5.8,<5.9\' \\\\\\n                \'tqdm>=4.59,<4.60\' \\\\\\n                \'pandas>=1.1,<1.2\' \\\\\\n                \'numpy>=1.10,<1.20\' \\\\\\n                \'scipy~=1.5.0\' \\\\\\n                \'scikit-learn~=0.24.1\' \\\\\\n                \'xgboost~=1.4.0\' \\\\\\n                \'lightgbm~=3.2.0\' \\\\\\n                \'dask~=2021.10.0\' \\\\\\n                \'distributed~=2021.10.0\' \\\\\\n                \'dask-ml~=2021.10.17\' \\\\\\n                \'adlfs~=0.7.0\' \\\\\\n                \'ipykernel~=6.0\' \\\\\\n                \'azureml-core==1.45.0\' \\\\\\n                \'azureml-defaults==1.45.0\' \\\\\\n                \'azureml-mlflow==1.45.0\' \\\\\\n                \'azureml-telemetry==1.45.0\'\\n\\n# This is needed for mpi to locate libpython\\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH","Enabled":false},"Spark":{"PrecachePackages":true}},"History":{"OutputCollection":true,"DirectoriesToWatch":["logs"],"EnableMLflowTracking":true},"Spark":{"Configuration":{"spark.app.name":"Azure ML Experiment","spark.yarn.maxAppAttempts":"1"}},"ParallelTask":{"MaxRetriesPerWorker":0,"WorkerCountPerNode":1},"BatchAi":{"NodeCount":0},"AmlCompute":{"RetainCluster":false,"ClusterMaxNodeCount":1},"AISuperComputer":{"InstanceType":"D2","ImageVersion":"pytorch-1.7.0","Interactive":false,"EnableAzmlInt":true,"SLATier":"Standard"},"Tensorflow":{"WorkerCount":1,"ParameterServerCount":1},"Mpi":{"ProcessCountPerNode":1},"PyTorch":{"CommunicationBackend":"nccl"},"Hdi":{"YarnDeployMode":"Cluster"},"ContainerInstance":{"CpuCores":2.0,"MemoryGb":3.5},"Docker":{"UseDocker":false,"SharedVolumes":true,"ShmSize":"2g"},"CommandReturnCodeConfig":{"ReturnCode":"Zero"},"EnvironmentVariables":{"AML_PARAMETER_learning_rate":"0.5"}},"SnapshotId":"94d70895-9222-4018-bdbc-2cb13af3f02d"}\n[2022-10-27 13:45:56Z] Starting run in Execution Service\n[2022-10-27 13:45:56Z] RunId:[550eedd7-8aab-43c5-8a9c-4c0e3092088a] ParentRunId:[5f85466f-1b84-40ae-ad01-2cf7a9d9cc04] ComputeTarget:[AmlCompute]\n[2022-10-27 13:45:57Z] Job is in progress. Execution status: Preparing.\n[2022-10-27 13:45:58Z] Job is in progress. Execution status: Queued.\n[2022-10-27 13:45:59Z] Job is in progress. Execution status: Queued.\n[2022-10-27 13: ...
#  'submittedBy': 'Trainer MlOps'}

# %% [markdown]
# This code finds all steps with the name Train model, and you select the first result located
# on the 0 index. This retrieves a StepRun object, which is for the step_02 folder you
# defined in the previous section. StepRun inherits from the base Run class, exposing
# the get_details_with_logs method that is also available in the ScriptRun class

# %% [markdown]
# ## Publishing a pipeline to expose it as an endpoint
#
# So far, you have defined a pipeline using the AzureML SDK. If you had to restart the
# kernel of your Jupyter notebook, you would lose the reference to the pipeline you defined,
# and you would have to rerun all the cells to recreate the pipeline object. The AzureML
# SDK allows you to publish a pipeline that effectively registers it as a versioned object
# within the workspace. Once a pipeline is published, it can be submitted without the
# Python code that constructed it

# %%
published_pipeline = pipeline.publish(
 "Loans training pipeline", 
 description="A pipeline to train a LightGBM model")

# %% [markdown]
# This code publishes the pipeline and returns a PublishedPipeline object, the
# versioned object registered within the workspace. The most interesting attribute of that
# object is the endpoint, which returns the REST endpoint URL to trigger the execution
# of the specific pipeline.
#
# To invoke the published pipeline, you will need an authentication header. To acquire this
# security header, you can use the InteractiveLoginAuthentication class, as seen
# in the following code snippet:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication
auth = InteractiveLoginAuthentication()
aad_token = auth.get_authentication_header()

# %% [markdown]
# Then you can use the Python requests package to make a POST request to the specific
# endpoint using the following code:

# %%
import requests
response = requests.post(published_pipeline.endpoint, 
 headers=aad_token, 
 json={"ExperimentName": "pipeline_run_test",
 "ParameterAssignments": {"learning_rate" : 0.02}})
print(f"Made a POST request to {published_pipeline.endpoint} and got {response.status_code}.")
# Out:
# Made a POST request to https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/afe91b36-9760-4bb8-9dd6-72761af8d4ef/resourceGroups/eymlops/providers/Microsoft.MachineLearningServices/workspaces/eymlws/PipelineRuns/PipelineSubmit/9539b997-83c7-48e6-920f-c36ba5419b52 and got 200.

# %%
print(f"The portal url for the run is {response.json()['RunUrl']}")
# Out:
# The portal url for the run is https://ml.azure.com/experiments/pipeline_run_test/runs/9d6dcbf5-e0d2-4efc-8194-1abae2a14256?tid=bdf67597-3a9e-4e19-958e-1d8222afa3de&wsid=/subscriptions/afe91b36-9760-4bb8-9dd6-72761af8d4ef/resourcegroups/eymlops/workspaces/eymlws

# %% [markdown]
# This code only needs the URL and not the actual pipeline code. If you ever lose
# the endpoint URL, you can retrieve it by code through the list method of the
# PublishedPipeline class, which enumerates all the published pipelines registered in
# the workspace. The preceding script invokes the REST endpoint using the HTTP POST
# verb and passing the value 0.02 as the learning_rate parameter.

# %% [markdown]
# Once you select a pipeline, you can trigger it using a graphical wizard that allows you to
# specify the pipeline parameters and the experiment under which the pipeline will execute.

# %% [markdown]
# ## Scheduling a recurring pipeline
#
# Being able to invoke a pipeline through the published REST endpoint is great when you
# have third-party systems that need to invoke a training process after a specific event has
# occurred. For example, suppose you are using Azure Data Factory to copy data from your
# on-premises databases. You could use the Machine Learning Execute Pipeline activity

# %% [markdown]
# If you wanted to schedule the pipeline to be triggered monthly, you would need to publish
# the pipeline as you did in the previous section, get the published pipeline ID, create
# a ScheduleRecurrence, and then create the Schedule.

# %%
from azureml.pipeline.core.schedule import ScheduleRecurrence, Schedule
from datetime import datetime

recurrence = ScheduleRecurrence(frequency="Month", 
                                interval=1, 
                                start_time = datetime.now())

schedule = Schedule.create(workspace=ws, name="pipeline-schedule",
                           pipeline_id=published_pipeline.id, 
                           experiment_name="pipeline-scheduled-run",
                           recurrence=recurrence,
                           wait_for_provisioning=True,
                           description="Schedule to retrain model")

print("Created schedule with id: {}".format(schedule.id))
# Out:
# Provisioning status: Completed
# Created schedule with id: 9f0ddb70-34dc-4716-aaf2-7a1d68c8e5f3

# %% [markdown]
# In this code, you define a ScheduleRecurrence with monthly frequency. By
# specifying the start_time = datetime.now(), you are preventing the immediate
# execution of the pipeline, which is the default behavior when creating a new Schedule.
# Once you have the recurrence you want to use, you can schedule the pipeline execution
# by calling the create method of the Schedule class. You are passing in the ID of the
# published_pipeline you want to trigger, and you specify the experiment name
# under which each execution will occur

# %% [markdown]
# ## If you want to disable a scheduled execution, you can use the disable method of the Schedule class. The following code disables all scheduled pipelines in your workspace:

# %%
from azureml.pipeline.core.schedule import Schedule

schedules = Schedule.list(ws, active_only=True) 
print("Your workspace has the following schedules set up:")
for schedule in schedules:
    print(f"Disabling {schedule.id} (Published pipeline: {schedule.pipeline_id}")
    schedule.disable(wait_for_provisioning=True)
# Out:
# Your workspace has the following schedules set up:
# Disabling 9f0ddb70-34dc-4716-aaf2-7a1d68c8e5f3 (Published pipeline: 9539b997-83c7-48e6-920f-c36ba5419b52
# Provisioning status: Completed

# %% [markdown]
# This code lists all active schedules within the workspace and then disables them one by
# one. Make sure you don't accidentally disable a pipeline that should have been scheduled
# in your workspace.
